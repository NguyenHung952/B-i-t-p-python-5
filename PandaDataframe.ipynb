# %%
# Cho tập tin dữ liệu auto.csv, và list headers sau:
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style","drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type","num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]
#Câu 1: Đọc dữ liệu từ tập tin auto.csv, kết hợp với list headers đã cho để tạo thành dataframe df có
#tiêu đề hoàn chỉnh.Liệt kê kiểu dữ liệu các cột của df. Liệt kê 5 dòng dữ liệu đầu tiên (head) của df
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("auto1.csv")
print("1. Liệt kê 5 dòng dữ liệu đầu tiên (head) của df")
df.columns = df.iloc[0] 
df = df[1:]
df.columns = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style","drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type","num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]

display(df.head(5))

#Câu 2: Trong tập dữ liệu, có một số dữ liệu bị thiếu đi kèm với dấu ? , bạn hãy thay thế các dữ liệu này
#thành NaN. In lại 5 dòng dữ liệu đầu tiên của df
print("2. In lại 5 dòng dữ liệu đầu tiên của df khi thay thành NaN")
df2 = df.replace('?', np.NaN)
display(df2.head(5))

#Câu 3: Đổi kiểu dữ liệu các cột thành kiểu dữ liệu đúng theo mô tả sau
# 1. make: alfa-romero, audi, bmw, chevrolet, dodge, honda, isuzu, jaguar, mazda, mercedes-benz, porsche,...
# 2. fuel-type: diesel, gas.
# 3. num-of-doors: four, two.
# 4. body-style: hardtop, wagon, sedan, hatchback, convertible.
# 5. drive-wheels: 4wd, fwd, rwd.
# 6. engine-location: front, rear.
# 7. wheel-base: continuous from 86.6 120.9.
# 8. length: continuous from 141.1 to 208.1.
# 9. width: continuous from 60.3 to 72.3.
# 10. height: continuous from 47.8 to 59.8.
# 11. curb-weight: continuous from 1488 to 4066.
# 12. engine-size: continuous from 61 to 326.
# 13. bore: continuous from 2.54 to 3.94.
# 14. stroke: continuous from 2.07 to 4.17.
# 15. horsepower: continuous from 48 to 288.
# 16. peak-rpm: continuous from 4150 to 6600.
# 17. city-mpg: continuous from 13 to 49.
# 18. highway-mpg: continuous from 16 to 54.
# 19. price: continuous from 5118 to 45400.

print("Danh sach cac hang du lieu: ")
titles = np.array(list(df.columns))
print(titles)

print("3. Đổi kiểu dữ liệu các cột thành kiểu dữ liệu: ")
titles[0],titles[1],titles[2],titles[3],titles[4],titles[5],titles[6],titles[7],titles[8],titles[9],titles[10],titles[11],titles[12],titles[13],titles[14],titles[15],titles[16],titles[17],titles[18],titles[19],titles[20],titles[21],titles[22],titles[23],titles[24],titles[25]=titles[2],titles[3],titles[5],titles[6],titles[7],titles[8],titles[9],titles[10],titles[11],titles[12],titles[13],titles[16],titles[18],titles[19],titles[21],titles[22],titles[23],titles[24],titles[25],titles[1],titles[4],titles[14],titles[15],titles[17],titles[20],titles[0]
df3 = df2[titles]
display(df3)

#Câu 4: Xóa bỏ các cột không cần thiết,chỉ giữ lại các cột:
# "make","fuel-type","num-of-doors","body-style","drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine size","bore","stroke","horsepower","peak-rpm","city-mpg","highway-mpg","price"

print(" Các cột không cần thiết: ") 
main = np.array(["make","fuel-type","num-of-doors","body-style","drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine size","bore","stroke","horsepower","peak-rpm","city-mpg","highway-mpg","price"])

delete1 = []
[ delete1.append(x) for x in titles if x not in main ]
series = pd.Series(delete1)
print(series)

print("4. Sau khi xóa bỏ các cột không cần thiết: ") 
delete2 = [df3 for df3 in df.columns if df3 in ["make","fuel-type","num-of-doors","body-style","drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine size","bore","stroke","horsepower","peak-rpm","city-mpg","highway-mpg","price"]]
df4 = df[delete2]
display(df4)

#Câu 5: Liệt kê số dòng có giá trị null trong các thuộc tính

print("5. Liệt kê số dòng có giá trị null trong các thuộc tính ")
df5 = df4[pd.isnull(df4).any(axis = 1)]
display(df5)

#Câu 6: Nếu cột 'num-of-doors' nếu có chứa giá trị NaN thì thay bằng giá trị phổ biến nhất của cột 
#'num-of-doors'


#Câu 7: Xóa tất cả các dòng có giá trị NaN trong cột 'price' (nếu có)

print("7. Xóa tất cả các dòng có giá trị NaN trong cột 'price': ")
df7_1 = df['price']
for  element in df7_1:
    if element == 'NaN':
        df7_1.drop('NaN')
        found = True
        break
if element != 'NaN':
    print("Khong co gia tri NaN trong cot 'price'")
        
#Câu 8: Các cột kiểu số khác nếu chứa giá trị NaN thì thay thế bằng giá trị trung bình
print("8. Các cột kiểu số khác nếu chứa giá trị NaN thì thay thế bằng giá trị trung bình")
df8 = df2.replace(np.nan, '', regex=True)
display(df8)

#Câu 9: Đặt lại chỉ mục (index) sau khi đã bỏ các dòng có giá trị NaN trong cột 'price' và các cập nhật trên 
#dữ liệu
#Câu 10: In thông tin thống kê chung của df

print("10. In thông tin thống kê chung của df")
print(df.info())

#Câu 11: Cho biết thông tin thống kê chung của các cột có kiểu dữ liệu là object.

print("11. Thông tin thống kê chung của các cột có kiểu dữ liệu là object:")
df11 = df2.columns[df2.dtypes == 'object']
display(df11)

#Câu 12: Cho biết số lượng của mỗi loại hệ thống dẫn động (drive-wheels)?
#Câu 13: Cho biết số lượng của mỗi loại động cơ (engine-location) ?
#Câu 14: Cho biết các giá trị của cột drive-wheels ?
#Câu 15: Tính giá (price) trung bình của mỗi loại hệ dẫn động (drive-wheels).
#Câu 16: Tính giá (price) trung bình của mỗi chiếc xe dựa vào kiểu dáng thân xe (body-style).
#Câu 17: Tính giá (price) trung bình mỗi kiểu dáng thân xe của các loại hệ dẫn động (drive-wheels).
#Câu 18: Từ câu trên, sử dụng hàm pivot để tạo bảng từ các nhóm cho dễ xem hơn.
#(drive-wheel thể hiện giá trị các dòng,  body-style thể hiện giá trị các cột)

#Câu 19: Vẽ biểu đồ thể hiện phân bố dữ liệu của cột price (histogram)

print("19. Vẽ biểu đồ thể hiện phân bố dữ liệu của cột price (histogram): ")
df19=df2['price'].astype(float)
print(df19.dtypes)
df19.plot.hist()

#Câu 21: Vẽ biểu đồ thể hiện giá trị giữa 'engine-size' và 'price'

print("21. Vẽ biểu đồ thể hiện giá trị giữa 'engine-size' và 'price'")
# Out:
# 1. Liệt kê 5 dòng dữ liệu đầu tiên (head) của df
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
# 5          1               158         audi       gas        std         four
#
#   body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 1  hatchback          rwd           front        94.5  ...          152
# 2      sedan          fwd           front        99.8  ...          109
# 3      sedan          4wd           front        99.4  ...          136
# 4      sedan          fwd           front        99.8  ...          136
# 5      sedan          fwd           front       105.8  ...          136
#
# ...
